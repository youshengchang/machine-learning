# %%
import numpy as np
import pandas as pd
import datetime
from datetime import datetime, date
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /opt/conda/lib/python3.5/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# /opt/conda/lib/python3.5/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
pd.DataFrame.replace?

# %%
foo = pd.DataFrame({'a' : [1,2,3,4], 'b' : ['(hi)', 'foo', 'fat(fat)', 'cat']})
foo
# Out:
#    a         b
# 0  1      (hi)
# 1  2       foo
# 2  3  fat(fat)
# 3  4       cat

# %%
test = (foo.b.str.match('([0-9A-Za-z ]+\([0-9A-Za-z]+\))|(\([0-9A-Za-z]+\))').str.len() > 0)
test.index[test.values == True]
# Out:
# /opt/conda/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: In future versions of pandas, match will change to always return a bool indexer.
#   if __name__ == '__main__':
# Int64Index([0, 2], dtype='int64')

# %%
energy = pd.read_excel('Energy Indicators.xls')
energy = energy.replace(to_replace = '...', value = np.NaN)
rename_dict = {'Environmental Indicators: Energy': 'Country','Unnamed: 3': 'Energy Supply','Unnamed: 4':'Energy Supply per Capita','Unnamed: 5':'% Renewable'}
energy.rename(columns = rename_dict ,inplace=True)
energy = energy.loc[16:242,'Country':]
country = energy.loc[237]['Country']
country = country[:country.find('(')].strip()
country
test = (energy.Country.str.match('([0-9A-Za-z ]+\([0-9A-Za-z ]+\))|(\([0-9A-Za-z ]+\))').str.len() > 0)
index_list = test[test.values == True].index
index_range = len(test[test.values == True].index)
for i in range(index_range):
    idx = index_list[i]
    country = energy.loc[idx]['Country']
    country = country[:country.find('(')].strip()
    energy.loc[idx]['Country'] = country
    print(energy.loc[idx]['Country'])
energy.columns
# Out:
# Bolivia
# Falkland Islands
# Iran
# Micronesia
# Sint Maarten
# Venezuela
# /opt/conda/lib/python3.5/site-packages/ipykernel/__main__.py:10: FutureWarning: In future versions of pandas, match will change to always return a bool indexer.
# Index(['Country', 'Energy Supply', 'Energy Supply per Capita', '% Renewable'], dtype='object')

# %%
#energy = pd.read_excel('Energy Indicators.xls', header= 17, skip_footer=38)
energy = pd.read_excel('Energy Indicators.xls')
energy = energy.replace(to_replace = '...', value = np.NaN)
rename_dict = {'Environmental Indicators: Energy': 'Country','Unnamed: 3': 'Energy Supply','Unnamed: 4':'Energy Supply per Capita','Unnamed: 5':'% Renewable'}
energy.rename(columns = rename_dict ,inplace=True)
energy = energy.loc[16:242,'Country':]
energy.loc[237]['Country']
energy['Energy Supply'] = energy['Energy Supply'] * 1000000
energy['Country'].replace(to_replace='[0-9]', value='', regex=True, inplace=True)
rename_country_dict = {'Republic of Korea':'South Korea', 'United States of America':'United States','United Kingdom of Great Britain and Northern Ireland':'United Kingdom','China, Hong Kong Special Administrative Region':'Hong Kong'}
energy.replace(to_replace=rename_country_dict, inplace=True) 
#energy.replace(to_replace = '([0-9A-Za-z ]+\([0-9A-Za-z ]+\))|(\([0-9A-Za-z ]+\))', value='', regex=True, inplace=True)
test = (energy.Country.str.match('([0-9A-Za-z ]+\([0-9A-Za-z ]+\))|(\([0-9A-Za-z ]+\))').str.len() > 0)
test[test.values == True].index
energy['Country'].str.strip()
energy.loc[237]['Country']
index_list = test[test.values == True].index
index_range = len(test[test.values == True].index)
for i in range(index_range):
    idx = index_list[i]
    country = energy.loc[idx]['Country']
    country = country[:country.find('(')].strip()
    #print(country)
    energy['Country'].replace(to_replace = energy.loc[idx]['Country'], value=country, inplace=True)
    #energy.loc[idx]['Country'] = country

energy = energy.set_index('Country')
energy.index
#test.index[test.values  == True ]
#energy.loc[energy['Country'].str.contains('United States of America')] = 'United States'
#energy.loc[energy['Country'].str.contains('United Kingdom of Great Britain and Northern Ireland')] = 'United Kingdom'
#energy.loc[energy['Country'].str.contains('China, Hong Kong Special Administrative Region')] = 'Hong Kong'

#foo.b.str.match('(f.*)').str.len() > 0
#energy.Country.str.match('(*)').str.len() > 0
#print(energy[energy['Country'] == 'South Korea']['Country'].values)
#print(energy[energy['Country'] == 'United States']['Country'].values)
#print(energy[energy['Country'] == 'United Kingdom']['Country'].values)
#print(energy[energy['Country'] == 'Hong Kong']['Country'].values)
#print(energy[energy['Country'] == 'Republic of Korea']['Country'].values)
#print(energy[energy['Country'] == 'United States of America']['Country'].values)
#print(energy[energy['Country'].str.contains('United States of America')]['Country'].values)
#print(energy[energy['Country'].str.contains('United Kingdom of Great Britain and Northern Ireland')]['Country'].values)
#print(energy[energy['Country'].str.contains('China, Hong Kong Special Administrative Region')]['Country'].values)
# Out:
# /opt/conda/lib/python3.5/site-packages/ipykernel/__main__.py:13: FutureWarning: In future versions of pandas, match will change to always return a bool indexer.
# Index(['Afghanistan', 'Albania', 'Algeria', 'American Samoa', 'Andorra',
#        'Angola', 'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia',
#        ...
#        'United States Virgin Islands', 'Uruguay', 'Uzbekistan', 'Vanuatu',
#        'Venezuela', 'Viet Nam', 'Wallis and Futuna Islands', 'Yemen', 'Zambia',
#        'Zimbabwe'],
#       dtype='object', name='Country', length=227)

# %%
pd.read_csv?
pd.Series.replace?

# %%
GDP = pd.read_csv('world_bank.csv', header = 4)

replace_dict = {"Korea, Rep.": "South Korea", 
"Iran, Islamic Rep.": "Iran",
"Hong Kong SAR, China": "Hong Kong"}
GDP['Country Name'].replace(to_replace=replace_dict, inplace=True)
GDP = GDP.set_index('Country Name')
GDP
# Out:
#                                                   Country Code  \
# Country Name
# Aruba                                                      ABW
# Andorra                                                    AND
# Afghanistan                                                AFG
# Angola                                                     AGO
# Albania                                                    ALB
# Arab World                                                 ARB
# United Arab Emirates                                       ARE
# Argentina                                                  ARG
# Armenia                                                    ARM
# American Samoa                                             ASM
# Antigua and Barbuda                                        ATG
# Australia                                                  AUS
# Austria                                                    AUT
# Azerbaijan                                                 AZE
# ...

# %%
ScimEn = pd.read_excel('scimagojr-3.xlsx')
ScimEn = ScimEn.set_index('Country')
ScimEn
# Out:
#                                 Rank  Documents  Citable documents  Citations  \
# Country
# China                              1     127050             126767     597237
# United States                      2      96661              94747     792274
# Japan                              3      30504              30287     223024
# United Kingdom                     4      20944              20357     206091
# Russian Federation                 5      18534              18301      34266
# Canada                             6      17899              17620     215003
# Germany                            7      17027              16831     140566
# India                              8      15005              14841     128763
# France                             9      13153              12973     130632
# South Korea                       10      11983              11923     114675
# Italy                             11      10964              10794     111850
# ...

# %%
pd.merge?

# %%
energy_countries = pd.merge(energy, GDP, right_index=True, left_index=True)
energy_countries = pd.merge(energy_countries, ScimEn,right_index=True, left_index=True)
columns = ['Rank', 'Documents', 'Citable documents', 'Citations', 'Self-citations', 'Citations per document', 'H index', 'Energy Supply', 'Energy Supply per Capita', '% Renewable', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015']
energy_countries = energy_countries[energy_countries['Rank'] < 16][columns]
len(energy_countries.columns)
len(energy_countries)
# Out:
# 15
